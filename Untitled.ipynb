# %%
import overpass

api = overpass.API(timeout=600, debug=True)

response = api.get('node["tourism"="alpine_hut"](41.836828,-5.009766,54.977614,29.267578);out 2;', responseformat="geojson")

# filtering for 50 points only
responseNew = response[0:51]
print(responseNew)
# Out:
# INFO:root:node["tourism"="alpine_hut"](41.836828,-5.009766,54.977614,29.267578);out 2;
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): overpass-api.de:443
# [out:json];node["tourism"="alpine_hut"](41.836828,-5.009766,54.977614,29.267578);out 2;out body;
# send: b'POST /api/interpreter HTTP/1.1\r\nHost: overpass-api.de\r\nUser-Agent: python-requests/2.22.0\r\nAccept-Encoding: gzip, deflate\r\nAccept: */*\r\nConnection: keep-alive\r\nAccept-Charset: utf-8;q=0.7,*;q=0.7\r\nContent-Length: 139\r\nContent-Type: application/x-www-form-urlencoded\r\n\r\n'
# send: b'data=%5Bout%3Ajson%5D%3Bnode%5B%22tourism%22%3D%22alpine_hut%22%5D%2841.836828%2C-5.009766%2C54.977614%2C29.267578%29%3Bout+2%3Bout+body%3B'
# DEBUG:urllib3.connectionpool:https://overpass-api.de:443 "POST /api/interpreter HTTP/1.1" 200 None
# reply: 'HTTP/1.1 200 OK\r\n'
# header: Date header: Server header: Vary header: Content-Encoding header: Keep-Alive header: Connection header: Transfer-Encoding header: Content-Type application/json
# [{"geometry": {"coordinates": [22.581838, 42.869887], "type": "Point"}, "id": 30361137, "properties": {"created_by": "Potlatch 0.9c", "name": "\u0445. \u0420\u0443\u0439", "operator": "\u0422\u0414 \u0420\u0443\u0439, \u0422\u0440\u044a\u043d", "tourism": "alpine_hut"}, "type": "Feature"}, {"geometry": {"coordinates": [6.724945, 45.816843], "type": "Point"}, "id": 30941606, "properties": {"addr:city": "Les Contamines-Montjoie", "addr:housenumber": "22", "addr:postcode": "74170", "addr:street": "Route du Plan du Moulin", "ele": "1164", "email": "chaletdescontamines@ffcam.fr", "name": "Chalet du CAF Contamines", "operator": "CAF", "phone": "+33 4 50 47 00 88", "tourism": "alpine_hut", "website": "https://chaletdescontamines.ffcam.fr/"}, "type": "Feature"}, {"geometry": {"coordinates": [22.581838, 42.869887], "type": "Point"}, "id": 30361137, "properties": {"created_by": "Potlatch 0.9c", "name": "\u0445. \u0420\u0443\u0439", "operator": "\u0422\u0414 \u0420\u0443\u0439, \u0422\u0440\u044a\u043d", "tourism": "alpine_hut"}, "type": "Feature"}, {"geometry": {"coordinates": [6.724945, 45.816843], "type": "Point"}, "id": 30941606, "properties": {"addr:city": "Les Contamines-Montjoie", "addr:housenumber": "22", "addr:postcode": "74170", "addr:street": "Route du Plan du Moulin", "ele": "1164", "email": "chaletdescontamines@ffcam.fr", "name": "Chalet du CAF Contamines", "operator": "CAF", "phone": "+33 4 50 47 00 88", "tourism": "alpine_hut", "website": "https://chaletdescontamines.ffcam.fr/"}, "type": "Feature"}, {"geometry": {"coordinates": [15.588133, 47.794515], "type": "Point"}, "id": 33519409, "properties": {"addr:city": "St. Aegyd am Neuwalde", "addr:postcode": "3193", "ele": "1499", "internet_access": "no", "name": "Gippelh\u00fctte", "note": "Mail: martin.hofecker@gmail.com, Bewirtschaftet w\u00e4hrend der Weidezeit ca. Mitte Juni bis Mitte September, N\u00e4chtigung m\u00f6glich: (16 Personen Lager), Mittwoch Ruhetag", "operator": "Martin Hofecker", "phone": "+43 664 8330536", "seasonal": "summer", "source": "http://www.staegyd.at;local_knowledge", "tourism": "alpine_hut", "website": "http://www.staegyd.at/Gippelhuette_1500_m_Seehoehe"}, "type": "Feature"}, {"geometry": {"coordinates": [7.771651, 46.5101], "type": "Point"}, "id": 33655239, "properties": {"addr:city": "Kandersteg", "addr:postcode": "3718", "addr:street": "Hoht\u00fcrli", "ele": "2840", "email": "info@bluemlisalphuette.com", "name": "Bl\u00fcmlisalph\u00fctte SAC", "name:ru": "\u0411\u043b\u044e\u043c\u043b\u0438\u0441\u0430\u043b\u044c\u043f\u0445\u044e\u0442\u0442\u0435", "operator": "SAC", "phone": "+4133 676 14 37", "reg_name": "Freiburger, Waadtl\u00e4nder und Berner Alpen", "tourism": "alpine_hut", "url": "http://www.bluemlisalphuette.com", "website": "http://www.bluemlisalphuette.com/typo3/", "wikidata": "Q887175"}, "type": "Feature"}, {"geometry": {"coordinates": [15.460085, 46.437434], "type": "Point"}, "id": 59264046, "properties": {"ele": "1181", "name": "\u0160tuhecov dom", "tourism": "alpine_hut"}, "type": "Feature"}, {"geometry": {"coordinates": [11.265801, 47.176795], "type": "Point"}, "id": 60447994, "properties": {"addr:city": "Grinzens", "addr:country": "AT", "addr:housenumber": "110", "addr:postcode": "6095", "amenity": "restaurant", "contact:mobile": "+43 650 5703391", "ele": "1673", "name": "Kemater Alm", "tourism": "alpine_hut", "website": "http://kemateralm.at"}, "type": "Feature"}, {"geometry": {"coordinates": [15.413679, 46.280709], "type": "Point"}, "id": 61104639, "properties": {"ele": "460m", "name": "Planinska postojanka PD Dramlje", "tourism": "alpine_hut"}, "type": "Feature"}, {"geometry": {"coordinates": [12.018873, 47.533265], "type": "Point"}, "id": 95823780, "properties": {"amenity": "restaurant", "contact:website": "http://www.buchackeralm.at", "cuisine": "austrian", "ele": "1450", "email": "buchackeralm@gmail.com", "name": "Almgasthof Buchacker", "opening_hours": "Apr-Oct; Mo off; Apr,May,Oct \"wetterabh\u00e4ngig\"", "phone": ...
